# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
# %load_ext rpy2

# %%
x = np.random.uniform(0, 10, 100)
y = 2*x + np.random.randn(len(x))

# %%
# %%R -i x,y
# lm = lm(y~x)
# print(summary(lm))
# plot(x, y, pch=19, col='blue')
# abline(coef(lm), col='red')
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.91023 -0.70417 -0.00182  0.79616  2.09215
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.10995    0.22225   0.495    0.622
# x            2.00620    0.03773  53.177   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.063 on 98 degrees of freedom
# Multiple R-squared:  0.9665,	Adjusted R-squared:  0.9662
# F-statistic:  2828 on 1 and 98 DF,  p-value: < 2.2e-16

# %%
coef = %R t = coef(lm)
print coef
# Out:
# [ 0.1099534   2.00620421]

# %%
X = np.random.rand(3, 4)
# %Rpush X
# %R print(x)
# Out:
#   [1] 2.066897694 0.320370029 1.594412181 1.142773322 4.786036773 7.589414870
#   [7] 5.222984487 6.233522154 4.933633892 8.771050569 0.365286496 0.001696758
#  [13] 2.532477506 5.090975528 6.663663486 7.831207297 4.979308977 6.388836255
#  [19] 7.486297352 1.302854662 5.878568954 5.462092890 6.178591817 9.990800318
#  [25] 5.002818883 6.642840734 7.077492727 4.231374278 8.107597315 4.662893087
#  [31] 6.297444323 4.078100638 5.954059617 9.440362239 5.498291574 6.928313673
#  [37] 5.017941379 7.063004675 7.400141557 2.113446128 2.039081403 3.839405045
#  [43] 0.797949640 4.390473030 2.503914853 4.625799988 2.542159377 5.378152448
#  [49] 5.134413785 1.734798414 3.528855209 8.344114265 5.247586732 7.291008315
#  [55] 0.799684460 4.810628642 5.986848945 8.984374782 9.974369390 9.813283510
#  [61] 6.053591815 2.393963152 2.761605246 1.266122534 8.054851794 4.056834147
#  [67] 4.416541467 0.629151389 9.327577237 9.690306156 3.299854671 2.536745626
#  [73] 3.275926965 9.123087846 1.069258643 7.079286949 0.690734753 7.311536673
#  [79] 4.051523173 1.279461016 9.232504345 1.604250010 5.204378184 7.906841071
#  [85] 0.188016076 8.128853301 9.927251234 5.616699637 7.630816944 4.070781322
#  [91] 3.458017642 5.491024733 3.920052992 9.726539553 8.311566005 9.256102052
#  [97] 0.189488655 9.015597428 6.789594896 7.150630446

# %%
df = pd.DataFrame({'id':range(10), 'value':np.random.rand(10), 'name':[chr(x) for x in range(97,107)]})
# %Rpush df
# %R print(class(df)); print(df)
# Out:
# [1] "data.frame"
#   id name      value
# 0  0    a 0.20316752
# 1  1    b 0.69309355
# 2  2    c 0.84063615
# 3  3    d 0.79147216
# 4  4    e 0.58256837
# 5  5    f 0.76065214
# 6  6    g 0.61260190
# 7  7    h 0.18776640
# 8  8    i 0.07384264
# 9  9    j 0.01660091

# %%
# %%R
# library(plyr)
# library(ggplot2)
# df$name = factor(df$name)
# df = mutate(df, exp=exp(df$value))
# print(df)
# print(ggplot(df) + geom_point(aes(x=id, y=exp, color=name)))
# Out:
#   id name      value      exp
# 0  0    a 0.20316752 1.225278
# 1  1    b 0.69309355 1.999893
# 2  2    c 0.84063615 2.317841
# 3  3    d 0.79147216 2.206643
# 4  4    e 0.58256837 1.790632
# 5  5    f 0.76065214 2.139671
# 6  6    g 0.61260190 1.845226
# 7  7    h 0.18776640 1.206552
# 8  8    i 0.07384264 1.076637
# 9  9    j 0.01660091 1.016739
